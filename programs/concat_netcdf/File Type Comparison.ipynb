# %%
import matplotlib.pyplot as plt
import netCDF4
import xarray
import numpy
import time

# %% [markdown]
# # Concatenating Files
#
# Using `xarray` we can concatenate \*.nc4 files into one large file for time series analysis and just as a sample for large data files. I use 9 full \*.nc4 files at 1.2GB each. I will time all of this to get an idea of how long this stuff takes.
#
# __This takes a long time (>10min), so be sure you want to do this__

# %%
do_it = False
if do_it:
    # get first time measurement
    tic = time.perf_counter()
    # open all the data sets at once
    data = xarray.open_mfdataset('../.downloads/202008*.nc4', \
                           combine = 'by_coords', concat_dim="time")
    # save the opened files in one file
    data.to_netcdf('../.downloads/combined.nc4')
    data.close()
    # get second time measurement and print result
    toc = time.perf_counter()
    print(f"Concatenated 3.2GB in {toc - tic:0.4f} seconds")

# %% [markdown]
# # Access Speed comparison between single and multiple files
#
# Using `xarray` to plot a time series of Bishkek for three days using the concatenated file and the single files.

# %%
# %matplotlib inline

# %%
# get first time measurement
tic = time.perf_counter()
ds = xarray.open_dataset('../.downloads/combined.nc4')  # NetCDF or OPeNDAP URL
lati = 42.8746; loni = 74.5698  # Bishkek

# Extract a dataset closest to specified point
dsloc = ds.sel(lon=loni, lat=lati, method='nearest')

# select a variable to plot
dsloc['PS'].plot()
ds.close()
# get second time measurement and print result
toc = time.perf_counter()
print(f"Plotted 3 days in {toc - tic:0.4f} seconds single file")
# Out:
# Plotted 3 days in 0.2343 seconds single file

# %%
# get first time measurement
tic = time.perf_counter()
ds = xarray.open_mfdataset('../.downloads/2020082*.nc4')  # NetCDF or OPeNDAP URL
lati = 42.8746; loni = 74.5698  # Bishkek

# Extract a dataset closest to specified point
dsloc = ds.sel(lon=loni, lat=lati, method='nearest')

# select a variable to plot
dsloc['PS'].plot()
ds.close()
# get second time measurement and print result
toc = time.perf_counter()
print(f"Plotted 3 days in {toc - tic:0.4f} seconds multiple files")
# Out:
# Plotted 3 days in 0.4839 seconds multiple files

# %% [markdown]
# We see that accessing a single file is a lot faster, which is to be expected. I repeat this experiment without the graphing

# %%
# get first time measurement
tic = time.perf_counter()
ds = xarray.open_dataset('../.downloads/combined.nc4')  # NetCDF or OPeNDAP URL
lati = 42.8746; loni = 74.5698  # Bishkek

# Extract a dataset closest to specified point
dsloc = ds.sel(lon=loni, lat=lati, method='nearest')

# select a variable to plot
#dsloc['PS'].plot()
ds.close()
# get second time measurement and print result
toc = time.perf_counter()
print(f"Plotted 3 days in {toc - tic:0.4f} seconds single file")

# get first time measurement
tic = time.perf_counter()
ds = xarray.open_mfdataset('../.downloads/2020082*.nc4')  # NetCDF or OPeNDAP URL
lati = 42.8746; loni = 74.5698  # Bishkek

# Extract a dataset closest to specified point
dsloc = ds.sel(lon=loni, lat=lati, method='nearest')

# select a variable to plot
#dsloc['PS'].plot()
ds.close()
# get second time measurement and print result
toc = time.perf_counter()
print(f"Plotted 3 days in {toc - tic:0.4f} seconds multiple files")
# Out:
# Plotted 3 days in 0.0731 seconds single file
# Plotted 3 days in 0.5219 seconds multiple files

# %%
# get first time measurement
tic = time.perf_counter()
ds = xarray.open_mfdataset('../.downloads/combined.nc4')  # NetCDF or OPeNDAP URL
#print(ds)
lati = 42.8746; loni = 74.5698  # Georges Bank

# Extract a dataset closest to specified point
dsloc = ds.sel(time='2020-08-21T21:00:00', method='nearest')

# select a variable to plot
dsloc['PS'].plot()
ds.close()
# get second time measurement and print result
toc = time.perf_counter()
print(f"Plotted 3 days in {toc - tic:0.4f} seconds one file")
# Out:
# Plotted 3 days in 0.2918 seconds one file

# %%
# get first time measurement
tic = time.perf_counter()
ds = xarray.open_mfdataset('../.downloads/2020082*.nc4')  # NetCDF or OPeNDAP URL
#print(ds)
lati = 42.8746; loni = 74.5698  # Georges Bank

# Extract a dataset closest to specified point
dsloc = ds.sel(time='2020-08-21T21:00:00', method='nearest')

# select a variable to plot
dsloc['PS'].plot()
ds.close()
# get second time measurement and print result
toc = time.perf_counter()
print(f"Plotted 3 days in {toc - tic:0.4f} seconds multiple files")
# Out:
# Plotted 3 days in 0.6026 seconds multiple files

# %%
# get first time measurement
tic = time.perf_counter()
ds = xarray.open_mfdataset('../.downloads/combined.nc4')  # NetCDF or OPeNDAP URL
#print(ds)
lati = 42.8746; loni = 74.5698  # Georges Bank

# Extract a dataset closest to specified point
dsloc = ds.sel(time='2020-08-21T21:00:00', method='nearest')

# select a variable to plot
ds.close()
# get second time measurement and print result
toc = time.perf_counter()
print(f"Plotted 3 days in {toc - tic:0.4f} seconds one file")
# get first time measurement
tic = time.perf_counter()
ds = xarray.open_mfdataset('../.downloads/2020082*.nc4')  # NetCDF or OPeNDAP URL
#print(ds)
lati = 42.8746; loni = 74.5698  # Georges Bank

# Extract a dataset closest to specified point
dsloc = ds.sel(time='2020-08-21T21:00:00', method='nearest')

# select a variable to plot
ds.close()
# get second time measurement and print result
toc = time.perf_counter()
print(f"Plotted 3 days in {toc - tic:0.4f} seconds multiple files")
# Out:
# Plotted 3 days in 0.2891 seconds one file
# Plotted 3 days in 0.3635 seconds multiple files

# %% [markdown]
# # Saving The File as NPY too
#
# Using `numpy` to save the data as \*.npy on disk.

# %%
# get first time measurement
tic = time.perf_counter()
# load the large file using numpy
data = xarray.open_dataset("../.downloads/combined.nc4")
#print(data.to_array())
data.close()
# get second time measurement and print result
toc = time.perf_counter()
print(f"{toc - tic:0.4f} seconds")
# Out:
# 0.0649 seconds

# %%
data = netCDF4.Dataset('../.downloads/combined.nc4', 'r')
print(data.variables)
data.close()
# Out:
# {'lon': <class 'netCDF4._netCDF4.Variable'>
# float64 lon(lon)
#     _FillValue: nan
#     long_name: longitude
#     units: degrees_east
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
# unlimited dimensions:
# current shape = (576,)
# filling on, 'lat': <class 'netCDF4._netCDF4.Variable'>
# float64 lat(lat)
#     _FillValue: nan
#     long_name: latitude
#     units: degrees_north
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
# unlimited dimensions:
# current shape = (361,)
# filling on, 'lev': <class 'netCDF4._netCDF4.Variable'>
# float64 lev(lev)
#     _FillValue: nan
#     long_name: vertical level
#     units: hPa
#     positive: down
#     coordinate: PLE
#     standard_name: PLE_level
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
# unlimited dimensions:
# current shape = (42,)
# filling on, 'time': <class 'netCDF4._netCDF4.Variable'>
# int64 time(time)
#     long_name: time
#     time_increment: 30000
#     begin_time: 0
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     units: hours since 2020-08-21 00:00:00
#     calendar: proleptic_gregorian
# unlimited dimensions:
# current shape = (24,)
# filling on, default _FillValue of -9223372036854775806 used, 'EPV': <class 'netCDF4._netCDF4.Variable'>
# float32 EPV(time, lev, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: ertels_potential_vorticity
#     units: K m+2 kg-1 s-1
#     fmissing_value: 1000000000000000.0
#     standard_name: ertels_potential_vorticity
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 42, 361, 576)
# filling on, 'H': <class 'netCDF4._netCDF4.Variable'>
# float32 H(time, lev, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: edge_heights
#     units: m
#     fmissing_value: 1000000000000000.0
#     standard_name: edge_heights
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 42, 361, 576)
# filling on, 'O3': <class 'netCDF4._netCDF4.Variable'>
# float32 O3(time, lev, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: ozone_mass_mixing_ratio
#     units: kg kg-1
#     fmissing_value: 1000000000000000.0
#     standard_name: ozone_mass_mixing_ratio
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 42, 361, 576)
# filling on, 'OMEGA': <class 'netCDF4._netCDF4.Variable'>
# float32 OMEGA(time, lev, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: vertical_pressure_velocity
#     units: Pa s-1
#     fmissing_value: 1000000000000000.0
#     standard_name: vertical_pressure_velocity
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 42, 361, 576)
# filling on, 'PHIS': <class 'netCDF4._netCDF4.Variable'>
# float32 PHIS(time, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: surface geopotential height
#     units: m+2 s-2
#     fmissing_value: 1000000000000000.0
#     standard_name: surface geopotential height
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 361, 576)
# filling on, 'PS': <class 'netCDF4._netCDF4.Variable'>
# float32 PS(time, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: surface_pressure
#     units: Pa
#     fmissing_value: 1000000000000000.0
#     standard_name: surface_pressure
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 361, 576)
# filling on, 'QI': <class 'netCDF4._netCDF4.Variable'>
# float32 QI(time, lev, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: mass_fraction_of_cloud_ice_water
#     units: kg kg-1
#     fmissing_value: 1000000000000000.0
#     standard_name: mass_fraction_of_cloud_ice_water
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 42, 361, 576)
# filling on, 'QL': <class 'netCDF4._netCDF4.Variable'>
# float32 QL(time, lev, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: mass_fraction_of_cloud_liquid_water
#     units: kg kg-1
#     fmissing_value: 1000000000000000.0
#     standard_name: mass_fraction_of_cloud_liquid_water
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 42, 361, 576)
# filling on, 'QV': <class 'netCDF4._netCDF4.Variable'>
# float32 QV(time, lev, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: specific_humidity
#     units: kg kg-1
#     fmissing_value: 1000000000000000.0
#     standard_name: specific_humidity
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 42, 361, 576)
# filling on, 'RH': <class 'netCDF4._netCDF4.Variable'>
# float32 RH(time, lev, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: relative_humidity_after_moist
#     units: 1
#     fmissing_value: 1000000000000000.0
#     standard_name: relative_humidity_after_moist
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 42, 361, 576)
# filling on, 'SLP': <class 'netCDF4._netCDF4.Variable'>
# float32 SLP(time, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: sea_level_pressure
#     units: Pa
#     fmissing_value: 1000000000000000.0
#     standard_name: sea_level_pressure
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 361, 576)
# filling on, 'T': <class 'netCDF4._netCDF4.Variable'>
# float32 T(time, lev, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: air_temperature
#     units: K
#     fmissing_value: 1000000000000000.0
#     standard_name: air_temperature
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 42, 361, 576)
# filling on, 'U': <class 'netCDF4._netCDF4.Variable'>
# float32 U(time, lev, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: eastward_wind
#     units: m s-1
#     fmissing_value: 1000000000000000.0
#     standard_name: eastward_wind
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 42, 361, 576)
# filling on, 'V': <class 'netCDF4._netCDF4.Variable'>
# float32 V(time, lev, lat, lon)
#     _FillValue: 1000000000000000.0
#     long_name: northward_wind
#     units: m s-1
#     fmissing_value: 1000000000000000.0
#     standard_name: northward_wind
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
#     add_offset: 0.0
#     scale_factor: 1.0
#     missing_value: 1000000000000000.0
# unlimited dimensions:
# current shape = (24, 42, 361, 576)
# filling on}
# <ipython-input-28-02c0a05692c8>:2: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   print(data.variables)
